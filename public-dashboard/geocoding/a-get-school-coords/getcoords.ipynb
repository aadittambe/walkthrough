# %%
import pandas as pd
import numpy as np
from geopy.geocoders import Nominatim
import re
import math
pd.set_option('display.max_columns', None)

# %%
data = pd.read_csv("../../data/processed/etl_school_list.csv",dtype = str).replace({'&#45':'-', r'&#39':'', '&amp':'and'}, regex=True).replace(r'\n',' ', regex=True) 
# data.columns = data.columns.str.strip().str.lower().str.replace(' ', '_').str.replace('(', '').str.replace(')', '').str.replace('.', '_')
data
# Out:
#                                               district  \
# 0                     Abbeville County School District
# 1                     Abbeville County School District
# 2                     Abbeville County School District
# 3                     Abbeville County School District
# 4                     Abbeville County School District
# ...                                                ...
# 1139              SC School For The Deaf And The Blind
# 1140              SC School For The Deaf And The Blind
# 1141              SC School For The Deaf And The Blind
# 1142  SC Governor's School For The Arts And Humanities
# 1143  SC Governor's School for Science and Mathematics
#
#                                         district_alt district_id  \
# 0                                       Abbeville 60     0160999
# 1                                       Abbeville 60     0160999
# 2                                       Abbeville 60     0160999
# ...

# %%
data["lat"] = ""
data["lon"] = ""

# %%
counter = 0
for index,row in data.iterrows():
    # numpy.isnan(number)
    address = f"{row['street']}, {row['city']}, {row['state']} {row['zip']}"
    # print(address)
    geolocator = Nominatim(user_agent="Aadit Tambe, University of Maryland")
    try:
        counter = counter + 1
        location = geolocator.geocode(address)
        data["lat"][index] = location.latitude
        data["lon"][index] = location.longitude
        print(str(counter) + ': done')
        # time.sleep(2)
    except:
        counter = counter + 1
        data["lat"][index] = "no_result"
        data["lon"][index] = "no_result"
        print(str(counter) +': no result')
        # time.sleep(2)
    # data.to_csv("../../data/processed/etl_school_full_data_with_coords.csv", index=False)
# Out:
# 1: done
# 2: done
# 3: done
# 4: done
# 6: no result
# 7: done
# 8: done
# 9: done
# 10: done
# 11: done
# 13: no result
# 15: no result
# 16: done
# 18: no result
# 20: no result
# 21: done
# 22: done
# 23: done
# 24: done
# 25: done
# 26: done
# 27: done
# 29: no result
# 30: done
# 32: no result
# 33: done
# 34: done
# 36: no result
# 37: done
# 38: done
# 39: done
# 40: done
# 41: done
# 42: done
# 43: done
# 44: done
# 45: done
# 47: no result
# 48: done
# 50: no result
# 52: no result
# 54: no result
# 55: done
# 57: no result
# 58: done
# 60: no result
# 62: no result
# 63: done
# 64: done
# 65: done
# 66: done
# 67: done
# 68: done
# 69: done
# 70: done
# 71: done
# 72: done
# 73: done
# 74: done
# 75: done
# 76: done
# 77: done
# 78: done
# 79: done
# 80: done
# 82: no result
# 83: done
# 84: done
# 85: done
# 86: done
# 87: done
# 89: no result
# 90: done
# 91: done
# 92: done
# 93: done
# 94: done
# 96: no result
# 97: done
# 99: no result
# 100: done
# 101: done
# ...

# %%
data.to_csv("../../data/processed/school_list_geocoded.csv", index=False)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3695 entries, 0 to 3694
# Data columns (total 36 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   district_x                        3695 non-null   object
#  1   school_x                          3695 non-null   object
#  2   school_id                         3695 non-null   int64
#  3   report_card_type_p_e_m_h_d        3695 non-null   object
#  4   street                            3663 non-null   object
#  5   city                              3663 non-null   object
#  6   state                             3671 non-null   object
#  7   zip                               3695 non-null   int64
#  8   gradespan                         3695 non-null   object
#  9   enrollment                        3695 non-null   int64
#  10  hdphone                           3663 non-null   object
# ...
